# %%
import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

csv_data = pandas.read_csv("spotify_artist_data.csv")

# %%
csv_data
# Out:
#       Unnamed: 0                                    Artist Name  \
# 0              1                                          Drake
# 1              2                                      Bad Bunny
# 2              3                                     Ed Sheeran
# 3              4                                     The Weeknd
# 4              5                                   Taylor Swift
# 5              6                                  Justin Bieber
# 6              7                                  Ariana Grande
# 7              8                                         Eminem
# 8              9                                    Post Malone
# 9             10                                            BTS
# 10            11                                       J Balvin
# 11            12                                     Kanye West
# 12            13                                  Billie Eilish
# 13            14                                     Juice WRLD
# ...
